# %%
# Importing packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading the GcExport.csv from the data folder
# Skipping the first row of the export since it only says "batting" and "pitching"
# With usecols we can filter on the columns we need

gc_stats = pd.read_csv('data/GcExport.csv', skiprows=1, usecols=['Number', 'First', 'Last', 'GP', "AVG", "OBP"])

# %%
gc_stats
# Out:
#       Number Last     First               GP                  AVG  \
# 0         00    H   Cameron               23                 .200
# 1          1    H   Addison               22                 .179
# 2          3    T   Kyndall               23                 .237
# 3          4    O       Mia               18                 .308
# 4          7    M   Camilla               11                 .188
# 5          9    V    Lauren               23                 .244
# 6         11    M   Addison                6                 .000
# 7         11    J     Syndi                3                 .000
# 8         13    W     Kyler               23                 .300
# 9         15    K  Brooklyn                4                 .000
# 10        16    C     Lyric                7                 .500
# 11        33  NaN        AC               23                 .459
# 12        44    R    Taylor               23                 .206
# 13        98    S       Ava               20                 .194
# 14    Totals  NaN       NaN               23                 .258
# 15       NaN  NaN       NaN              NaN                  NaN
# 16  Glossary  NaN       NaN  GP=Games played  AVG=Batting average
#
#                        OBP
# 0                     .535
# 1                     .303
# 2                     .370
# 3                     .357
# 4                     .435
# 5                     .279
# 6                     .833
# 7                     .000
# 8                     .364
# 9                     .286
# 10                    .615
# 11                    .583
# 12                    .341
# 13                    .306
# 14                    .406
# 15                     NaN
# 16  OBP=On-base percentage
